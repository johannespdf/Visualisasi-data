# %% [markdown]
#  1. Tentukan data yang akan anda gunakan dalam visualisasi
#  Data yang saya gunakan adalah Spotify Most Streamed Songs.csv
#  dalam data ini terdapat 25 atribut,dalam 25 atribut ini saya menggunakan dua atribut untuk divisualisasikan yaitu Tahun rilis , persentase untuk dance dari lagu.
#  2. A. Tujuan
# Mengetahui Tren: Tujuan utama dari visualisasi ini adalah untuk menganalisis tren dalam rilis musik dan bagaimana mereka berhubungan dengan keberadaan mereka di Spotify Charts. Ini dapat membantu dalam memahami pola popularitas musik dari tahun ke tahun.
#
#     B.Pengguna
# Musisi dan Produser Musik: Mereka mungkin ingin memahami tren popularitas untuk merencanakan rilis musik di masa mendatang. Marketer dan Analis Data: Mereka akan tertarik dalam mengidentifikasi tren untuk kampanye pemasaran atau pengembangan strategi. Penggemar Musik: Penggemar dapat menggunakan data ini untuk melihat bagaimana musik favorit mereka diterima di pasar.
#
#     C.Fungsi
# Analisis Data: Menyediakan informasi visual yang membantu pengguna menganalisis bagaimana tahun rilis mempengaruhi keberadaan lagu di Spotify Charts.Identifikasi Pola: Memungkinkan pengguna untuk mengidentifikasi pola tertentu, seperti tahun-tahun di mana musik tertentu cenderung lebih populer.Perbandingan: Memfasilitasi perbandingan antara lagu-lagu dari tahun yang berbeda dalam hal performa di Spotify.
#
#     D.Tone
# Informatif dan Profesional: Visualisasi harus memiliki tone yang bersifat informatif, dengan desain yang profesional dan mudah dimengerti. Penggunaan warna yang kontras dan jelas, serta penjelasan yang cukup dalam label, akan membantu dalam menyampaikan pesan dengan baik.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Spotify Most Streamed Songs.csv")
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# Buatlah visualisasi dengan mengunakan library python seperti matplotlib, seaborn atau tools lain
#
# berikut contoh visualisasi sederhana untuk informasi dan analisis yang bisa membantu melihat performa lagu yang ada di spotify.Sebagai contoh dapat kita simpulkan bahwa Tiap Tahunnya lagu yang rilis memiliki tingkat percentase yang berbeda untuk menari,Percentase nya meningkat pada tahun 2000 - 2020.

# %%
plt.bar(df['released_year'], df['danceability_%'])
plt.title("Bar Chart")
plt.xlabel('released_year')
plt.ylabel('danceability_%')
plt.show()
